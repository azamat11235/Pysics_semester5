# %% [markdown]
# # QR-разложение вращениями Гивенса

# %% [markdown]
# ## 0. Общая часть

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg.blas
import mymodule
from numba import njit

# %%
scipy.ALLOW_THREADS = 1
np.ALLOW_THREADS = 1

# %%
def restore_q(q):
    size = int((1 + np.sqrt(1 + 4*q.shape[0]))/2)
    res = np.eye(size)
    iq = q.shape[0] - 1
    for i in range(size-2, -1, -1,):
        for j in range(size-1, i, -1):
            s = q[iq]
            c = q[iq-1]
            scipy.linalg.blas.drot(res[i], res[j], c, -s, offx=i, offy=i, overwrite_x=1, overwrite_y=1)
            iq -= 2
    return res

def test(qr_func):
    eps = 1e-10
    size = 100
    a = np.random.rand(size, size)
    a_ = np.copy(a)
    q = restore_q(qr_func(a))
    for i in range(size-1):
        for j in range(i+1, size):
            if (a[j,i] > eps):
                return 1
    if np.linalg.norm(q@a - a_, ord='fro') > eps:
        return 2
    if np.linalg.norm(q@q.T - np.eye(size), ord='fro') > eps:
        return 3
    return 0

def compute_times(sizes, qr_func):
    times = []
    for size in sizes:
        a = np.random.rand(size, size)
        t = %timeit -o qr_func(a)
        times.append(t.average)
    return times

# %%
sizes = [32, 64, 128, 256]

# %% [markdown]
# ## 1. Python

# %%
def compute_params(aii, aji):
    c =  aii / np.sqrt(aii * aii + aji * aji)
    s = -aji / np.sqrt(aii * aii + aji * aji)
    return (c, s)

def rotate(xi, xj, c, s):
    xi_ = xi * c - xj * s
    xj_ = xi * s + xj * c
    return (xi_, xj_)

def qr(a):
    size = a.shape[0]
    q = []
    for i in range(size-1):
        for j in range(i+1, size):
            c, s = compute_params(a[i, i], a[j, i])
            q.extend([c, -s])
            for k in range(i, size):
                xi, xj = rotate(a[i, k], a[j, k], c, s)
                a[i, k] = xi
                a[j, k] = xj
    return np.asarray(q)

# %%
test(qr)
# Out:
# 0

# %%
res1 = compute_times(sizes, qr)
# Out:
# 19.7 ms ± 2.52 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 128 ms ± 24.6 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 957 ms ± 227 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 7.69 s ± 346 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## 2. Numpy

# %%
def qr_np(a):
    size = a.shape[0]
    q = []
    for i in range(size-1):
        for j in range(i+1, size):
            c, s = compute_params(a[i, i], a[j, i])
            ai = a[i] * c - a[j] * s
            aj = a[i] * s + a[j] * c
            a[i] = ai
            a[j] = aj
            q.extend([c, -s])
    return np.asarray(q)

# %%
test(qr_np)
# Out:
# 0

# %%
res2 = compute_times(sizes, qr_np)
# Out:
# 7.32 ms ± 1.69 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 38.2 ms ± 2.38 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 151 ms ± 19.4 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 543 ms ± 93.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# ## 3. Numpy + Numba

# %%
@njit
def qr_np_numba(a):
    size = a.shape[0]
    q = []
    for i in range(size-1):
        for j in range(i+1, size):
            c = a[i,i] / np.sqrt(a[i,i] * a[i,i] + a[j,i] * a[j,i])
            s = -a[j,i] / np.sqrt(a[i,i] * a[i,i] + a[j,i] * a[j,i])
            ai = a[i] * c - a[j] * s
            aj = a[i] * s + a[j] * c
            a[i] = ai
            a[j] = aj
            q.extend([c, -s])
    return np.asarray(q)

# %%
test(qr_np_numba)
# Out:
# 0

# %%
res3 = compute_times(sizes, qr_np_numba)
# Out:
# 338 µs ± 58.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 4.36 ms ± 562 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 18.9 ms ± 3.8 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 146 ms ± 47.1 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ## 4. Numba

# %%
@njit
def qr_numba(a):
    size = a.shape[0]
    q_size = size * (size - 1)
    q = []
    for i in range(size-1):
        for j in range(i+1, size):
            aii = a[i, i]
            aji = a[j, i]
            c = aii / np.sqrt(aii * aii + aji * aji)
            s = -aji / np.sqrt(aii * aii + aji * aji)
            q.extend([c, -s])
            for k in range(i, size):
                xi = a[i, k]
                xj = a[j, k]
                a[i, k] = xi * c - xj * s
                a[j, k] = xi * s + xj * c
    return np.asarray(q)

# %%
test(qr_numba)
# Out:
# 0

# %%
res4 = compute_times(sizes, qr_numba)
# Out:
# 115 µs ± 18.3 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 1.82 ms ± 518 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 13.9 ms ± 2.88 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 129 ms ± 32.8 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ## 5. SciPy

# %%
def qr_sp(a):
    size = a.shape[0]
    q = []
    for i in range(size-1):
        for j in range(i+1, size):
            c, s = scipy.linalg.blas.drotg(a[i,i], a[j,i])
            scipy.linalg.blas.drot(a[i], a[j], c, s, offx=i, offy=i, overwrite_x=1, overwrite_y=1)
            q.extend([c, s])
    return np.asarray(q)

# %%
test(qr_sp)
# Out:
# 0

# %%
res5 = compute_times(sizes, qr_sp)
# Out:
# 1.6 ms ± 241 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 4.72 ms ± 1.09 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 32.9 ms ± 1.09 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 129 ms ± 26.4 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ## 6. C (swig)

# %%
# небольшой тест
size = 100
a = np.random.rand(size, size)
q = np.empty(size**2 - size)
a_ = np.copy(a)
mymodule.qr(a, q)
q = restore_q(q)
np.linalg.norm(q@a - a_, ord='fro')
# Out:
# 7.055608688360463e-14

# %%
res6 = []
for size in sizes:
    a = np.random.rand(size, size)
    q = np.empty(size**2 - size)
    t = %timeit -o mymodule.qr(a, q)
    res6.append(t.average)
# Out:
# 203 µs ± 23.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.28 ms ± 316 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 7.94 ms ± 2.2 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 61.6 ms ± 3.97 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## 7. Сравнение функций

# %%
labels = ['Python', 'NumPy', 'Numpy + Numba', 'Numba', 'SciPy', 'C (swig)']
colors = ['g', 'b', 'r', 'y', 'k', 'c']

# %%
fig, ax = plt.subplots(1, 3, figsize=(20, 5))
for i in range(len(labels)):
    ax[0].plot(sizes, eval('res%d'%(i+1)), label=labels[i], color=colors[i])
for i in range(1,len(labels)):
    ax[1].plot(sizes, eval('res%d'%(i+1)), label=labels[i], color=colors[i])
for i in range(2,len(labels)):
    ax[2].plot(sizes, eval('res%d'%(i+1)), label=labels[i], color=colors[i])
for i in range(3):
    ax[i].grid()
    ax[i].set_xlabel('size')
    ax[i].set_ylabel('time (s.)')
    ax[i].set_xticks(sizes)
    ax[i].legend()
plt.subplots_adjust(wspace=0.25)

# %%
fig, ax = plt.subplots(2, 3, figsize=(20, 10))
for i in range(2):
    for j in range(3):
        ax[i, j].set_xlabel('size')
        ax[i, j].set_ylabel('time (s.)')
        ax[i, j].plot(sizes, eval('res%d'%(i+j+1)), label=labels[3*i+j], color=colors[3*i+j])
        ax[i, j].legend(loc='upper left')
        ax[i, j].grid()
        ax[i, j].set_xticks(sizes)
plt.subplots_adjust(wspace=0.3, hspace=0.3)
plt.show()
